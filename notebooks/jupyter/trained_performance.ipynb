# %% [markdown]
# # Overview
#
# This figure shows the performance of the NN trained on elevation data
# inferring D/K on the test set. The plot is in log-log space because the
# value in question is a ratio. The network was not trained on the log
# space
#
# ## Publication plan
#
# -   Paper: TBD
# -   Slides: first results slide
# -   Poster: Main results panel
#
# ## Data source
#
# csv from this file
#
# ## todo items
#
# # setup
#
# set up python environment for plotting, styles, etc
#
# ``` python
# from m
# ```
#
# # Load Data
#
# ``` python
# PERFORMANC = ""
# DATA_TYPE = ""
# TARGET = "DoK"
# all_df = pd.read_csv(PERFORMANCE_CSV)
# filtered_df = all_df[(all_df['data']==DATA_TYPE) & (all_df['target']==TARGET)]
# ```
#
# # plotting function
#
# ``` python
# def make_plot(ax):
#     sns.kdeplot(filtered_df, x='log_true', y='log_pred', levels=4, fill=True, alpha=0.9, ax=ax)
# ```
#
# # generate versions
